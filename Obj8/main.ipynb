# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
life = pd.read_csv('life_expectancy.csv')
population = pd.read_csv('population.csv')
population = population.rename(columns={'District.Name': 'District_Name', 'Neighborhood.Name': 'Neighborhood_Name'})
life
# Out:
#                                      Neighborhood  2006-2010  2007-2011  \
# 0                                        el Raval       87.5       84.9
# 1                                  el Barri Gòtic       88.0       84.3
# 2                                  la Barceloneta       88.2       85.3
# 3           Sant Pere, Santa Caterina i la Ribera       88.9       85.9
# 4                                   el Fort Pienc       89.7       87.1
# ..                                            ...        ...        ...
# 141  Diagonal Mar i el Front Marítim del Poblenou       82.1       80.9
# 142                         el Besòs i el Maresme       80.2       78.1
# 143                       Provençals del Poblenou       80.4       78.8
# 144                      Sant Martí de Provençals       81.9       79.5
# 145                           la Verneda i la Pau       82.0       79.7
#
#      2008-2012  2009-2013  2010-2014  Gender
# 0         84.7       84.9       85.3  Female
# 1         84.4       87.5       84.4  Female
# 2         84.4       86.3       84.7  Female
# 3         86.1       85.5       85.3  Female
# 4         87.2       87.7       86.7  Female
# ..         ...        ...        ...     ...
# 141       81.2       79.7       82.2    Male
# 142       78.4       79.8       79.6    Male
# 143       79.4       80.1       81.5    Male
# 144       79.7       80.5       80.2    Male
# 145       79.9       80.5       80.6    Male
#
# [146 rows x 7 columns]

# %%
life = life.sort_values(by=['2006-2010'], ascending=True)
life.head(60)
# Out:
#                                      Neighborhood  2006-2010  2007-2011  \
# 130                                 Baró de Viver       74.2       71.2
# 119                                   Can Peguera       74.7       72.3
# 112                                       Montbau       77.1       74.9
# 73                                       el Raval       77.9       75.1
# 125                              la Trinitat Nova       78.0       75.9
# 75                                 la Barceloneta       78.3       75.0
# 94          Vallvidrera, el Tibidabo i les Planes       78.9       77.6
# 122                                  les Roquetes       79.2       76.7
# 102                                      la Salut       79.6       77.6
# 142                         el Besòs i el Maresme       80.2       78.1
# 123                                        Verdun       80.2       77.8
# 143                       Provençals del Poblenou       80.4       78.8
# 127                              Ciutat Meridiana       80.4       78.0
# 129                             la Trinitat Vella       80.4       77.7
# 131                                 el Bon Pastor       80.4       77.8
# 83                   el Poble Sec - Parc Montjuïc       80.6       78.2
# 109                                     el Carmel       80.7       78.7
# 118                           el Turó de la Peira       80.9       79.0
# 120                                  la Guineueta       80.9       78.6
# 76          Sant Pere, Santa Caterina i la Ribera       80.9       78.0
# 87                                    Hostafrancs       81.2       78.9
# 79                         la Dreta de l'Eixample       81.2       78.9
# 74                                 el Barri Gòtic       81.3       78.6
# 101                                       el Coll       81.4       79.6
# 140                                   el Poblenou       81.4       78.7
# 115                                         Horta       81.4       78.8
# 106                                      Can Baró       81.5       78.9
# 86                          la Font de la Guatlla       81.5       77.9
# 108                          la Font d'en Fargues       81.6       79.7
# 82                                    Sant Antoni       81.7       79.3
# 107                                   el Guinardó       81.7       79.7
# 90                                          Sants       81.7       79.5
# 132                                   Sant Andreu       81.7       79.7
# 117                                         Porta       81.7       79.8
# 134                      el Congrés i els Indians       81.7       79.2
# 124                                la Prosperitat       81.7       79.3
# 116                 Vilapicina i la Torre Llobeta       81.8       79.1
# 111                      Sant Genís dels Agudells       81.8       80.0
# 103                             la Vila de Gràcia       81.8       79.0
# 137                                       el Clot       81.9       80.3
# 144                      Sant Martí de Provençals       81.9       79.5
# 145                           la Verneda i la Pau       82.0       79.7
# 121                                     Canyelles       82.0       79.3
# 141  Diagonal Mar i el Front Marítim del Poblenou       82.1       80.9
# 81                 la Nova Esquerra de l'Eixample       82.1       79.9
# 46                                    Can Peguera       82.2       79.7
# 110                                  la Teixonera       82.3       79.6
# 80                l'Antiga Esquerra de l'Eixample       82.3       79.8
# 138             el Parc i la Llacuna del Poblenou       82.4       79.8
# 57                                  Baró de Viver       82.4       79.9
# 135                                         Navas       82.5       80.4
# 100                     Vallcarca i els Penitents       82.6       80.2
# 104            el Camp d'en Grassot i Gràcia Nova       82.7       80.6
# 136                    el Camp de l'Arpa del Clot       82.9       80.4
# 91                                      les Corts       83.0       81.1
# 77                                  el Fort Pienc       83.0       80.7
# 85                              la Marina de Port       83.1       80.3
# 78                             la Sagrada Família       83.2       80.6
# 21          Vallvidrera, el Tibidabo i les Planes       83.4       80.5
# 39                                        Montbau       83.5       81.3
#
#      2008-2012  2009-2013  2010-2014  Gender
# 130        NaN       81.3       74.6    Male
# 119       71.8       77.9       75.0    Male
# 112       75.9       80.4       77.5    Male
# 73        75.7       76.2       76.5    Male
# 125       75.4       79.8       76.6    Male
# 75        75.8       78.6       75.9    Male
# 94        77.8       81.0       79.0    Male
# 122       76.8       69.0       77.6    Male
# 102       78.6       80.1       78.9    Male
# 142       78.4       79.8       79.6    Male
# 123       78.1       79.6       77.7    Male
# 143       79.4       80.1       81.5    Male
# 127       78.2       78.3       79.3    Male
# 129       79.0       80.6       80.8    Male
# 131       78.0       80.3       78.1    Male
# 83        78.7       82.0       78.8    Male
# 109       79.0       77.8       79.4    Male
# 118       80.0       77.0       81.3    Male
# 120       78.8       80.1       81.0    Male
# 76        77.7       78.8       78.3    Male
# 87        78.7       78.2       79.8    Male
# 79        79.3       79.1       80.1    Male
# 74        78.9       79.5       78.7    Male
# 101       80.7       80.1       81.4    Male
# 140       78.4       78.8       79.5    Male
# 115       79.4       79.7       80.7    Male
# 106       80.3       78.8       81.1    Male
# 86        78.1       84.2       78.8    Male
# 108       79.8       80.5       80.8    Male
# 82        79.4       80.9       79.8    Male
# 107       80.1       77.4       80.2    Male
# 90        80.2       82.4       81.6    Male
# 132       80.3       81.8       81.2    Male
# 117       79.9       81.1       81.0    Male
# 134       79.5       80.9       80.3    Male
# 124       80.1       77.7       80.4    Male
# 116       79.7       79.8       79.8    Male
# 111       81.3       79.6       81.5    Male
# 103       79.1       79.4       79.9    Male
# 137       80.6       78.9       81.3    Male
# 144       79.7       80.5       80.2    Male
# 145       79.9       80.5       80.6    Male
# 121       79.8       75.8       79.7    Male
# 141       81.2       79.7       82.2    Male
# 81        80.0       81.4       81.0    Male
# 46        80.3       87.2       85.1  Female
# 110       79.8       79.6       80.4    Male
# 80        80.3       80.3       80.8    Male
# 138       80.2       81.8       80.5    Male
# 57         NaN       88.0       85.7  Female
# 135       80.6       80.5       82.3    Male
# 100       80.6       80.9       80.9    Male
# 104       81.0       80.0       81.4    Male
# 136       81.1       82.4       81.9    Male
# 91        81.4       81.8       82.4    Male
# 77        80.9       80.2       81.4    Male
# 85        79.9       83.0       80.0    Male
# 78        81.0       79.2       81.3    Male
# 21        80.4       88.5       82.2  Female
# 39        81.9       87.3       83.9  Female

# %%
life_s = pd.concat([life.loc[[130, 119]], life.loc[[91, 89]]])
life_s
# Out:
#       Neighborhood  2006-2010  2007-2011  2008-2012  2009-2013  2010-2014  \
# 130  Baró de Viver       74.2       71.2        NaN       81.3       74.6
# 119    Can Peguera       74.7       72.3       71.8       77.9       75.0
# 91       les Corts       83.0       81.1       81.4       81.8       82.4
# 89   Sants - Badal       83.5       81.2       81.2       83.5       82.0
#
#     Gender
# 130   Male
# 119   Male
# 91    Male
# 89    Male

# %%
select = life.sort_values(by=['2006-2010'], ascending=True)
select = life.query('Neighborhood == "Baró de Viver" | Neighborhood == "Can Peguera" | Neighborhood == "les Corts" | Neighborhood == "Sants - Badal"')
select = select.sort_values(by=['Neighborhood'])
select = select[['Neighborhood', '2006-2010','Gender']]
# Out:
#       Neighborhood  2006-2010  Gender
# 130  Baró de Viver       74.2    Male
# 57   Baró de Viver       82.4  Female
# 119    Can Peguera       74.7    Male
# 46     Can Peguera       82.2  Female
# 89   Sants - Badal       83.5    Male
# 16   Sants - Badal       88.4  Female
# 91       les Corts       83.0    Male
# 18       les Corts       89.4  Female

# %%
g = sns.catplot(
    data=select, kind="bar",
    x="Neighborhood", y="2006-2010", hue="Gender")
