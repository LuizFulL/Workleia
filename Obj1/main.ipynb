# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Objetivo: Distribuição etária da população para um determinado ano e distrito;

# %%
population = pd.read_csv('population.csv')
population
# Out:
#        Year  District.Code District.Name  Neighborhood.Code  \
# 0      2017              1  Ciutat Vella                  1
# 1      2017              1  Ciutat Vella                  2
# 2      2017              1  Ciutat Vella                  3
# 3      2017              1  Ciutat Vella                  4
# 4      2017              2      Eixample                  5
# ...     ...            ...           ...                ...
# 70075  2013             10    Sant Martí                 69
# 70076  2013             10    Sant Martí                 70
# 70077  2013             10    Sant Martí                 71
# 70078  2013             10    Sant Martí                 72
# 70079  2013             10    Sant Martí                 73
#
#                                   Neighborhood.Name  Gender   Age  Number
# 0                                          el Raval    Male   0-4     224
# 1                                    el Barri Gòtic    Male   0-4      50
# 2                                    la Barceloneta    Male   0-4      43
# 3             Sant Pere, Santa Caterina i la Ribera    Male   0-4      95
# 4                                     el Fort Pienc    Male   0-4     124
# ...                                             ...     ...   ...     ...
# 70075  Diagonal Mar i el Front Marítim del Poblenou  Female  >=95      21
# 70076                         el Besòs i el Maresme  Female  >=95      25
# 70077                       Provençals del Poblenou  Female  >=95      31
# 70078                      Sant Martí de Provençals  Female  >=95      38
# 70079                           la Verneda i la Pau  Female  >=95      47
#
# [70080 rows x 8 columns]

# %% [markdown]
# DataFrame Completo com todas as informações!! e "District_Code Corrigido

# %%
population = population.rename(columns={'District.Name': 'District_Name', 'District.Code': 'District_Code'})
population
# Out:
#        Year  District_Code District_Name  Neighborhood.Code  \
# 0      2017              1  Ciutat Vella                  1
# 1      2017              1  Ciutat Vella                  2
# 2      2017              1  Ciutat Vella                  3
# 3      2017              1  Ciutat Vella                  4
# 4      2017              2      Eixample                  5
# ...     ...            ...           ...                ...
# 70075  2013             10    Sant Martí                 69
# 70076  2013             10    Sant Martí                 70
# 70077  2013             10    Sant Martí                 71
# 70078  2013             10    Sant Martí                 72
# 70079  2013             10    Sant Martí                 73
#
#                                   Neighborhood.Name  Gender   Age  Number
# 0                                          el Raval    Male   0-4     224
# 1                                    el Barri Gòtic    Male   0-4      50
# 2                                    la Barceloneta    Male   0-4      43
# 3             Sant Pere, Santa Caterina i la Ribera    Male   0-4      95
# 4                                     el Fort Pienc    Male   0-4     124
# ...                                             ...     ...   ...     ...
# 70075  Diagonal Mar i el Front Marítim del Poblenou  Female  >=95      21
# 70076                         el Besòs i el Maresme  Female  >=95      25
# 70077                       Provençals del Poblenou  Female  >=95      31
# 70078                      Sant Martí de Provençals  Female  >=95      38
# 70079                           la Verneda i la Pau  Female  >=95      47
#
# [70080 rows x 8 columns]

# %% [markdown]
# Distrito: Ciutat Vella
# Ano: 2017

# %%
population = population.query('Year=="2017" & District_Name=="Ciutat Vella"')
population.reset_index(inplace=True)
population
# Out:
#      index  Year  District_Code District_Name  Neighborhood.Code  \
# 0        0  2017              1  Ciutat Vella                  1
# 1        1  2017              1  Ciutat Vella                  2
# 2        2  2017              1  Ciutat Vella                  3
# 3        3  2017              1  Ciutat Vella                  4
# 4       73  2017              1  Ciutat Vella                  1
# ..     ...   ...            ...           ...                ...
# 763  13873  2017              1  Ciutat Vella                  4
# 764  13943  2017              1  Ciutat Vella                  1
# 765  13944  2017              1  Ciutat Vella                  2
# 766  13945  2017              1  Ciutat Vella                  3
# 767  13946  2017              1  Ciutat Vella                  4
#
#                          Neighborhood.Name  Gender    Age  Number
# 0                                 el Raval    Male    0-4     224
# 1                           el Barri Gòtic    Male    0-4      50
# 2                           la Barceloneta    Male    0-4      43
# 3    Sant Pere, Santa Caterina i la Ribera    Male    0-4      95
# 4                                 el Raval    Male    0-4     216
# ..                                     ...     ...    ...     ...
# 763  Sant Pere, Santa Caterina i la Ribera  Female  90-94      26
# 764                               el Raval  Female   >=95      75
# 765                         el Barri Gòtic  Female   >=95      33
# 766                         la Barceloneta  Female   >=95      39
# 767  Sant Pere, Santa Caterina i la Ribera  Female   >=95      39
#
# [768 rows x 9 columns]

# %%
population.Age[population.Age == '0-4'] = '00-4'
population.Age[population.Age == '5-9'] = '05-9'
population
# Out:
# <ipython-input-25-2a16b2a97aec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population.Age[population.Age == '0-4'] = '00-4'
# C:\Python39\lib\site-packages\pandas\core\series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-25-2a16b2a97aec>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population.Age[population.Age == '5-9'] = '05-9'
#      index  Year  District_Code District_Name  Neighborhood.Code  \
# 0        0  2017              1  Ciutat Vella                  1
# 1        1  2017              1  Ciutat Vella                  2
# 2        2  2017              1  Ciutat Vella                  3
# 3        3  2017              1  Ciutat Vella                  4
# 4       73  2017              1  Ciutat Vella                  1
# ..     ...   ...            ...           ...                ...
# 763  13873  2017              1  Ciutat Vella                  4
# 764  13943  2017              1  Ciutat Vella                  1
# 765  13944  2017              1  Ciutat Vella                  2
# 766  13945  2017              1  Ciutat Vella                  3
# 767  13946  2017              1  Ciutat Vella                  4
#
#                          Neighborhood.Name  Gender    Age  Number
# 0                                 el Raval    Male   00-4     224
# 1                           el Barri Gòtic    Male   00-4      50
# 2                           la Barceloneta    Male   00-4      43
# 3    Sant Pere, Santa Caterina i la Ribera    Male   00-4      95
# 4                                 el Raval    Male   00-4     216
# ..                                     ...     ...    ...     ...
# 763  Sant Pere, Santa Caterina i la Ribera  Female  90-94      26
# 764                               el Raval  Female   >=95      75
# 765                         el Barri Gòtic  Female   >=95      33
# 766                         la Barceloneta  Female   >=95      39
# 767  Sant Pere, Santa Caterina i la Ribera  Female   >=95      39
#
# [768 rows x 9 columns]

# %%
age_pop = population[['Age', 'Number']]
age = age_pop.groupby(by=['Age']).sum().index.tolist()
age_pop
# Out:
#        Age  Number
# 0     00-4     224
# 1     00-4      50
# 2     00-4      43
# 3     00-4      95
# 4     00-4     216
# ..     ...     ...
# 763  90-94      26
# 764   >=95      75
# 765   >=95      33
# 766   >=95      39
# 767   >=95      39
#
# [768 rows x 2 columns]

# %%
age_pop1 = age_pop.groupby(by=['Age']).sum().sort_values(by=['Age'],ascending=True)
age_pop1
# Out:
#        Number
# Age
# 00-4     3855
# 05-9     3750
# 10-14    3384
# 15-19    3526
# 20-24    6223
# 25-29   11506
# 30-34   11802
# 35-39   11085
# 40-44    9271
# 45-49    7474
# 50-54    6374
# 55-59    5162
# 60-64    4065
# 65-69    3367
# 70-74    2977
# 75-79    2425
# 80-84    2403
# 85-89    1671
# 90-94     839
# >=95      228

# %%
line,ax = plt.subplots(figsize=(12,6)) 
ax = sns.lineplot(data=age_pop1).set_title('Distribuição Etária em 2017 no distrito de Ciutat Vella')
