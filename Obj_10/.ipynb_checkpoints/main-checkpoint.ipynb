# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import folium
from folium import plugins

# %% [markdown]
# # CONTROLAR A QUALIDADE DO AR

# %%
Air_quality = pd.read_csv('air_quality_Nov2017.csv')
Air_quality = Air_quality.rename(columns={'Air Quality': 'Air_Quality'})
Air_quality
# Out:
#                        Station Air_Quality  Longitude  Latitude O3 Hour  \
# 0            Barcelona - Sants        Good     2.1331   41.3788     NaN
# 1         Barcelona - Eixample    Moderate     2.1538   41.3853      0h
# 2           Barcelona - Gràcia        Good     2.1534   41.3987      0h
# 3       Barcelona - Ciutadella        Good     2.1874   41.3864      0h
# 4      Barcelona - Vall Hebron        Good     2.1480   41.4261      0h
# ...                        ...         ...        ...       ...     ...
# 5739    Barcelona - Ciutadella        Good     2.1874   41.3864     22h
# 5740   Barcelona - Vall Hebron        Good     2.1480   41.4261     22h
# 5741   Barcelona - Palau Reial        Good     2.1151   41.3875     22h
# 5742      Barcelona - Poblenou        Good     2.2045   41.4039     NaN
# 5743  Barcelona - Observ Fabra        Good     2.1239   41.4183     22h
#
#      O3 Quality  O3 Value NO2 Hour NO2 Quality  NO2 Value PM10 Hour  \
# 0           NaN       NaN       0h        Good       84.0       NaN
# 1          Good       1.0       0h    Moderate      113.0        0h
# 2          Good      10.0       0h        Good       73.0       NaN
# 3          Good       2.0       0h        Good       86.0       NaN
# 4          Good       7.0       0h        Good       69.0       NaN
# ...         ...       ...      ...         ...        ...       ...
# 5739       Good      10.0      22h        Good       57.0       NaN
# 5740       Good      32.0      22h        Good       31.0       22h
# 5741       Good      40.0      22h        Good       20.0       22h
# 5742        NaN       NaN      22h        Good       70.0       22h
# 5743       Good      64.0      22h        Good       21.0       22h
#
#      PM10 Quality  PM10 Value         Generated   Date Time
# 0             NaN         NaN   01/11/2018 0:00  1541027104
# 1            Good        36.0   01/11/2018 0:00  1541027104
# 2             NaN         NaN   01/11/2018 0:00  1541027104
# 3             NaN         NaN   01/11/2018 0:00  1541027104
# 4             NaN         NaN   01/11/2018 0:00  1541027104
# ...           ...         ...               ...         ...
# 5739          NaN         NaN  30/11/2018 23:00  1543615502
# 5740         Good        21.0  30/11/2018 23:00  1543615502
# 5741         Good        15.0  30/11/2018 23:00  1543615502
# 5742         Good        25.0  30/11/2018 23:00  1543615502
# 5743         Good        12.0  30/11/2018 23:00  1543615502
#
# [5744 rows x 15 columns]

# %%
Air_Moderate = Air_quality.query('Air_Quality == "Moderate"')
Air_Moderate = Air_Moderate[['Station', 'Air_Quality', 'Longitude', 'Latitude', 'Generated']]
Air_Moderate.groupby(['Station']).count()
# Out:
#                          Air_Quality  Longitude  Latitude  Generated
# Station
# Barcelona - Eixample              83         83        83         83
# Barcelona - Gràcia                22         22        22         22
# Barcelona - Palau Reial            3          3         3          3
# Barcelona - Poblenou              22         22        22         22

# %%
Air_Moderate.groupby(['Generated']).count()
hour = Air_Moderate['Generated'].str.split(' ')
hours = []
days = []
for i in hour:
    days.append(i[0])
    hours.append(i[1])    
Air_Moderate['Generated'] = days
Air_Moderate['Hour'] = hours

# %%
Air_Moderate.groupby(['Hour']).count().sort_values(['Station'], ascending=False)
# Out:
#        Station  Air_Quality  Longitude  Latitude  Generated
# Hour
# 10:00       12           12         12        12         12
# 21:00       11           11         11        11         11
# 20:00       10           10         10        10         10
# 22:00       10           10         10        10         10
# 11:00        9            9          9         9          9
# 9:00         7            7          7         7          7
# 23:00        5            5          5         5          5
# 6:00         5            5          5         5          5
# 8:00         5            5          5         5          5
# 7:00         5            5          5         5          5
# 0:00         5            5          5         5          5
# 1:00         4            4          4         4          4
# 12:00        4            4          4         4          4
# 16:00        4            4          4         4          4
# 2:00         4            4          4         4          4
# 3:00         4            4          4         4          4
# 4:00         4            4          4         4          4
# 5:00         4            4          4         4          4
# 18:00        4            4          4         4          4
# 17:00        4            4          4         4          4
# 19:00        3            3          3         3          3
# 15:00        3            3          3         3          3
# 14:00        2            2          2         2          2
# 13:00        2            2          2         2          2

# %% [markdown]
# Conclusão, conseguimos filtrar os bairros com mais ocorrência de air equal moderate, e seus respectivos horários.

# %% [markdown]
# _________________________________________________________________________________________________

# %% [markdown]
# # REORGANIZAR AS PARADAS DE AUTOCARRO

# %%
bus_stops = pd.read_csv('bus_stops.csv')
bus_stops = bus_stops.rename(columns={'District.Name': 'District_Name'})
bus_stops
# Out:
#       Code       Transport  Longitude   Latitude          Bus.Stop  \
# 0     K014    Day bus stop   2.171619  41.413744        BUS -192--
# 1     K014    Day bus stop   2.134902  41.420222        BUS -124--
# 2     K014    Day bus stop   2.162913  41.423187        BUS -117--
# 3     K014    Day bus stop   2.163667  41.422899        BUS -117--
# 4     K014    Day bus stop   2.120212  41.397209        BUS -130--
# ...    ...             ...        ...        ...               ...
# 3157  K014    Day bus stop   2.183887  41.422024        BUS -191--
# 3158  K014    Day bus stop   2.176710  41.446419     BUS -127-81--
# 3159  K015  Night bus stop   2.144596  41.411446      NITBUS -N4--
# 3160  K014    Day bus stop   2.142256  41.371176  BUS -91-115-V5--
# 3161  K015  Night bus stop   2.134932  41.398495      NITBUS -N7--
#
#             District_Name          Neighborhood.Name
# 0          Horta-Guinardó                el Guinardó
# 1                  Gràcia  Vallcarca i els Penitents
# 2          Horta-Guinardó       la Font d'en Fargues
# 3          Horta-Guinardó       la Font d'en Fargues
# 4     Sarrià-Sant Gervasi                     Sarrià
# ...                   ...                        ...
# 3157          Sant Andreu   el Congrés i els Indians
# 3158           Nou Barris               les Roquetes
# 3159               Gràcia  Vallcarca i els Penitents
# 3160       Sants-Montjuïc                 la Bordeta
# 3161  Sarrià-Sant Gervasi     Sant Gervasi - Galvany
#
# [3162 rows x 7 columns]

# %%
bus_stopsD = bus_stops.groupby(by=['District_Name']).count().sort_values(by=['Code'],ascending=False)
bus_stopsD
# Out:
#                      Code  Transport  Longitude  Latitude  Bus.Stop  \
# District_Name
# Sarrià-Sant Gervasi   439        439        439       439       439
# Sants-Montjuïc        415        415        415       415       415
# Eixample              405        405        405       405       405
# Horta-Guinardó        389        389        389       389       389
# Sant Martí            356        356        356       356       356
# Nou Barris            330        330        330       330       330
# Sant Andreu           228        228        228       228       228
# Gràcia                210        210        210       210       210
# Les Corts             207        207        207       207       207
# Ciutat Vella          167        167        167       167       167
#
#                      Neighborhood.Name
# District_Name
# Sarrià-Sant Gervasi                439
# Sants-Montjuïc                     415
# Eixample                           405
# Horta-Guinardó                     389
# Sant Martí                         356
# Nou Barris                         330
# Sant Andreu                        228
# Gràcia                             210
# Les Corts                          207
# Ciutat Vella                       167

# %%
Code_bus = bus_stops[['Transport','Code']].groupby('Code')["Transport"].value_counts().to_frame()
Code_bus["Bus_Number"] = Code_bus["Transport"]
Code_bus = Code_bus.drop('Transport', axis='columns')
Code_bus.loc[['K014','K015']]
# Out:
#                      Bus_Number
# Code Transport
# K014 Day bus stop          2324
# K015 Night bus stop         828

# %%
bus_stopsDN = bus_stops.query('Code == "K014" | Code == "K015"')
stops = bus_stopsDN.groupby(['District_Name', 'Transport']).count().sort_values(by=['District_Name'],ascending=False)
stops = stops.reset_index()
stops = stops.rename(columns={'Code' : 'N°_Stop', 'Transport': 'P_Stop'})
stops = stops[['District_Name','P_Stop', 'N°_Stop']]
stops
# Out:
#           District_Name          P_Stop  N°_Stop
# 0   Sarrià-Sant Gervasi  Night bus stop      106
# 1   Sarrià-Sant Gervasi    Day bus stop      333
# 2        Sants-Montjuïc  Night bus stop       78
# 3        Sants-Montjuïc    Day bus stop      334
# 4            Sant Martí  Night bus stop      121
# 5            Sant Martí    Day bus stop      235
# 6           Sant Andreu  Night bus stop       66
# 7           Sant Andreu    Day bus stop      161
# 8            Nou Barris  Night bus stop       76
# 9            Nou Barris    Day bus stop      254
# 10            Les Corts  Night bus stop       45
# 11            Les Corts    Day bus stop      162
# 12       Horta-Guinardó  Night bus stop       80
# 13       Horta-Guinardó    Day bus stop      309
# 14               Gràcia  Night bus stop       44
# 15               Gràcia    Day bus stop      166
# 16             Eixample  Night bus stop      154
# 17             Eixample    Day bus stop      245
# 18         Ciutat Vella  Night bus stop       53
# 19         Ciutat Vella    Day bus stop      114

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(data=stops, x='District_Name', y='N°_Stop', hue='P_Stop',ax=ax).set_title('Bus Stop')
x = plt.xticks(rotation=90)

# %%
day_stop = stops.query('P_Stop == "Day bus stop"')
day_stop = day_stop[['District_Name','N°_Stop']]
night_stop = stops.query('P_Stop == "Night bus stop"')
night_stop = night_stop[['District_Name', 'N°_Stop']]


Stops = stops.groupby(['District_Name']).count().reset_index().sort_values(['District_Name'], ascending=False)
Stops = Stops[['District_Name', 'P_Stop']]
Stops = Stops.merge(day_stop, how ='inner', on ='District_Name')
Stops = Stops.rename(columns={'N°_Stop': 'N°_DayStop'}).drop('P_Stop', axis='columns')
Stops = Stops.merge(night_stop, how = 'inner', on = 'District_Name')
Stops = Stops.rename(columns={'N°_Stop': 'N°_NightStop'})
Stops
# Out:
#          District_Name  N°_DayStop  N°_NightStop
# 0  Sarrià-Sant Gervasi         333           106
# 1       Sants-Montjuïc         334            78
# 2           Sant Martí         235           121
# 3          Sant Andreu         161            66
# 4           Nou Barris         254            76
# 5            Les Corts         162            45
# 6       Horta-Guinardó         309            80
# 7               Gràcia         166            44
# 8             Eixample         245           154
# 9         Ciutat Vella         114            53

# %%
Stops.sort_values(['N°_DayStop'])
# Out:
#          District_Name  N°_DayStop  N°_NightStop
# 9         Ciutat Vella         114            53
# 3          Sant Andreu         161            66
# 5            Les Corts         162            45
# 7               Gràcia         166            44
# 2           Sant Martí         235           121
# 8             Eixample         245           154
# 4           Nou Barris         254            76
# 6       Horta-Guinardó         309            80
# 0  Sarrià-Sant Gervasi         333           106
# 1       Sants-Montjuïc         334            78

# %%
Stops.sort_values(['N°_NightStop'])
# Out:
#          District_Name  N°_DayStop  N°_NightStop
# 7               Gràcia         166            44
# 5            Les Corts         162            45
# 9         Ciutat Vella         114            53
# 3          Sant Andreu         161            66
# 4           Nou Barris         254            76
# 1       Sants-Montjuïc         334            78
# 6       Horta-Guinardó         309            80
# 0  Sarrià-Sant Gervasi         333           106
# 2           Sant Martí         235           121
# 8             Eixample         245           154

# %%
fig, ax =plt.subplots(1,2,figsize=(15,7))
g = sns.barplot(data=Stops, x='District_Name', y='N°_DayStop', color="salmon", ax=ax[0]).set_title('Bus_Stop on Day')
g1 = sns.barplot(data=Stops, x='District_Name', y='N°_NightStop', palette="Blues_d", ax=ax[1]).set_title('Bus_Stop on Night')
x = plt.xticks(rotation=90)
y = plt.sca(ax[0])
z = plt.xticks(rotation=90)

# %% [markdown]
# Concluimos quais distritos tem mais e menos paradas durante o dia e durante a noite

# %% [markdown]
# _______________________________________________________

# %% [markdown]
# # MELHORAR A RELAÇÃO COM OS HABITANTES

# %%
population = pd.read_csv('population.csv')
population = population.rename(columns={'District.Name': 'District_Name', 'Neighborhood.Name':'Neighborhood_Name'})
population = population.query('Year=="2017" & District_Name == "Eixample"')
pop_Ciut = population.groupby(['Neighborhood_Name'])['Number'].sum().to_frame().reset_index()
pop_Ciut
# Out:
#                  Neighborhood_Name  Number
# 0                      Sant Antoni   38345
# 1                    el Fort Pienc   32016
# 2  l'Antiga Esquerra de l'Eixample   42284
# 3           la Dreta de l'Eixample   44052
# 4   la Nova Esquerra de l'Eixample   58180
# 5               la Sagrada Família   51539

# %%
gender_Ciut = population[['Neighborhood_Name', 'Gender', 'Number']]
male_Ciut = gender_Ciut.query('Gender=="Male"').groupby(['Neighborhood_Name']).sum().reset_index()
female_Ciut = gender_Ciut.query('Gender=="Female"').groupby(['Neighborhood_Name']).sum().reset_index()

gender_Ciut = gender_Ciut.groupby(['Neighborhood_Name']).sum().reset_index()
gender_Ciut = gender_Ciut.rename(columns={'Number': 'Total'})

male_Ciut = male_Ciut.rename(columns={'Number': 'Male'})
female_Ciut = female_Ciut.rename(columns={'Number': 'Female'})

gender_Ciut = gender_Ciut.merge(male_Ciut, how='inner', on='Neighborhood_Name')
gender_Ciut = gender_Ciut.merge(female_Ciut, how='inner', on='Neighborhood_Name')
gender_Ciut
# Out:
#                  Neighborhood_Name  Total   Male  Female
# 0                      Sant Antoni  38345  18165   20180
# 1                    el Fort Pienc  32016  15054   16962
# 2  l'Antiga Esquerra de l'Eixample  42284  19632   22652
# 3           la Dreta de l'Eixample  44052  20412   23640
# 4   la Nova Esquerra de l'Eixample  58180  27012   31168
# 5               la Sagrada Família  51539  23587   27952

# %%
immigrants = pd.read_csv('immigrants_by_nationality.csv')
immigrants = immigrants.rename(columns={'District Name': 'District_Name', 'Neighborhood Name':'Neighborhood_Name'})
immigrants = immigrants.query('Year=="2017" & District_Name == "Eixample"')
immi_Ciut = immigrants.groupby(['Neighborhood_Name'])['Number'].sum().to_frame().reset_index()
immi_Ciut
# Out:
#                  Neighborhood_Name  Number
# 0                      Sant Antoni    2490
# 1                    el Fort Pienc    2237
# 2  l'Antiga Esquerra de l'Eixample    3467
# 3           la Dreta de l'Eixample    3200
# 4   la Nova Esquerra de l'Eixample    4062
# 5               la Sagrada Família    3591

# %%
imm_sex = pd.read_csv('immigrants_emigrants_by_sex.csv')
imm_sex = imm_sex.rename(columns={'District Name': 'District_Name', 'Neighborhood Name':'Neighborhood_Name'})
imm_sex = imm_sex.query('Year=="2017" & District_Name == "Eixample"')
imm_sex = imm_sex[['Neighborhood_Name', 'Gender', 'Immigrants']]

# %%
imm_male = imm_sex.query('Gender=="Male"').groupby(['Neighborhood_Name']).sum().reset_index()
imm_female = imm_sex.query('Gender=="Female"').groupby(['Neighborhood_Name']).sum().reset_index()

immi_Ciut = immi_Ciut.rename(columns={'Number': 'Total'})

imm_male = imm_male.rename(columns={'Immigrants': 'Male'})
imm_female = imm_female.rename(columns={'Immigrants': 'Female'})

genderimmi_Ciut = immi_Ciut.merge(imm_male, how='inner', on='Neighborhood_Name')
genderimmi_Ciut = genderimmi_Ciut.merge(imm_female, how='inner', on='Neighborhood_Name')
genderimmi_Ciut = genderimmi_Ciut.rename(columns={'Total': 'Total_Immigrants', 'Male': 'Male_Immi', 'Female': 'Female_immi'})
genderimmi_Ciut
# Out:
#                  Neighborhood_Name  Total_Immigrants  Male_Immi  Female_immi
# 0                      Sant Antoni              2490       1253         1237
# 1                    el Fort Pienc              2237       1082         1155
# 2  l'Antiga Esquerra de l'Eixample              3467       1693         1774
# 3           la Dreta de l'Eixample              3200       1543         1657
# 4   la Nova Esquerra de l'Eixample              4062       1927         2135
# 5               la Sagrada Família              3591       1693         1898

# %%
poptotal_Ciu = gender_Ciut.merge(genderimmi_Ciut, how='inner', on='Neighborhood_Name')
poptotal_Ciu
# Out:
#                  Neighborhood_Name  Total   Male  Female  Total_Immigrants  \
# 0                      Sant Antoni  38345  18165   20180              2490
# 1                    el Fort Pienc  32016  15054   16962              2237
# 2  l'Antiga Esquerra de l'Eixample  42284  19632   22652              3467
# 3           la Dreta de l'Eixample  44052  20412   23640              3200
# 4   la Nova Esquerra de l'Eixample  58180  27012   31168              4062
# 5               la Sagrada Família  51539  23587   27952              3591
#
#    Male_Immi  Female_immi
# 0       1253         1237
# 1       1082         1155
# 2       1693         1774
# 3       1543         1657
# 4       1927         2135
# 5       1693         1898

# %%
total = poptotal_Ciu['Total'].sum()
totals = poptotal_Ciu[['Neighborhood_Name', 'Total']]
totals['% pop_Eix'] = (poptotal_Ciu['Total']*100)/total
totals['% pop_Eix'] = totals['% pop_Eix'].round(1)

totals['% neigh_imm'] = (poptotal_Ciu['Total_Immigrants']*100)/poptotal_Ciu['Total']
totals['% neigh_imm'] = totals['% neigh_imm'].round(1)
totals
# Out:
# <ipython-input-21-b8229c7f6acb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totals['% pop_Eix'] = (poptotal_Ciu['Total']*100)/total
# <ipython-input-21-b8229c7f6acb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totals['% pop_Eix'] = totals['% pop_Eix'].round(1)
# <ipython-input-21-b8229c7f6acb>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totals['% neigh_imm'] = (poptotal_Ciu['Total_Immigrants']*100)/poptotal_Ciu['Total']
# <ipython-input-21-b8229c7f6acb>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totals['% neigh_imm'] = totals['% neigh_imm'].round(1)
#                  Neighborhood_Name  Total  % pop_Eix  % neigh_imm
# 0                      Sant Antoni  38345       14.4          6.5
# 1                    el Fort Pienc  32016       12.0          7.0
# 2  l'Antiga Esquerra de l'Eixample  42284       15.9          8.2
# 3           la Dreta de l'Eixample  44052       16.5          7.3
# 4   la Nova Esquerra de l'Eixample  58180       21.8          7.0
# 5               la Sagrada Família  51539       19.3          7.0

# %% [markdown]
# _____________________________________________________________________

# %% [markdown]
# # PREVENIR ACIDENTES

# %%
accidents = pd.read_csv('accidents_2017.csv')
accidents
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 2      2017S010210           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# 1      Número 3 Zona Franca / Número 50 Zona Franca  ...     Friday
# 2      Litoral (Besòs)                               ...     Friday
# 3      Número 3 Zona Franca                          ...     Friday
# 4      Las Navas de Tolosa                           ...   Thursday
# ...                                                  ...        ...
# 10334  Litoral (Llobregat)                           ...    Tuesday
# 10335  PL MONTERREY                                  ...  Wednesday
# 10336  Litoral (Llobregat)                           ...   Thursday
# 10337  Litoral (Besòs)                               ...     Friday
# 10338  CIUTAT D'ASUNCIÓN                             ...     Sunday
#
#            Month  Day  Hour Part of the day  Mild injuries  Serious injuries  \
# 0        October   13     8         Morning              2                 0
# 1      September    1    13         Morning              2                 0
# 2       December    8    21       Afternoon              5                 0
# 3           July   21     2           Night              1                 0
# 4            May   25    14       Afternoon              1                 0
# ...          ...  ...   ...             ...            ...               ...
# 10334      April   25     8         Morning              1                 0
# 10335      March    8    12         Morning              1                 0
# 10336   December   28     8         Morning              1                 0
# 10337       July   14    14       Afternoon              1                 0
# 10338    January    8    20       Afternoon              0                 0
#
#        Victims  Vehicles involved  Longitude   Latitude
# 0            2                  2   2.125624  41.340045
# 1            2                  2   2.120452  41.339426
# 2            5                  2   2.167356  41.360885
# 3            1                  2   2.124529  41.337668
# 4            1                  3   2.185272  41.416365
# ...        ...                ...        ...        ...
# 10334        1                  3   2.201800  41.392004
# 10335        1                  2   2.206013  41.443445
# 10336        1                  2   2.205607  41.443894
# 10337        1                  2   2.205118  41.444824
# 10338        0                  1   2.200956  41.437125
#
# [10339 rows x 15 columns]

# %%
coordenadas = []
for lat, lng in zip(accidents.Latitude.values[:10339], accidents.Longitude.values[:10339]):
    coordenadas.append([lat, lng])

# %%
mapa = folium.Map(width=1000,height=1000)
mapa.add_child(plugins.HeatMap(coordenadas, radius=5, blur=3.5))
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7bc1bccbd8974b4384303be471741af9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%201000.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%201000.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7bc1bccbd8974b4384303be471741af9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7bc1bccbd8974b4384303be471741af9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7bc1bccbd8974b4384303be471741af9%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...
