# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
accidents = pd.read_csv('accidents_2017.csv')
accidents
# Out:
#                     Id District Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 2      2017S010210           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# 1      Número 3 Zona Franca / Número 50 Zona Franca  ...     Friday
# 2      Litoral (Besòs)                               ...     Friday
# 3      Número 3 Zona Franca                          ...     Friday
# 4      Las Navas de Tolosa                           ...   Thursday
# ...                                                  ...        ...
# 10334  Litoral (Llobregat)                           ...    Tuesday
# 10335  PL MONTERREY                                  ...  Wednesday
# 10336  Litoral (Llobregat)                           ...   Thursday
# 10337  Litoral (Besòs)                               ...     Friday
# 10338  CIUTAT D'ASUNCIÓN                             ...     Sunday
#
#            Month  Day  Hour Part of the day  Mild injuries  Serious injuries  \
# 0        October   13     8         Morning              2                 0
# 1      September    1    13         Morning              2                 0
# 2       December    8    21       Afternoon              5                 0
# 3           July   21     2           Night              1                 0
# 4            May   25    14       Afternoon              1                 0
# ...          ...  ...   ...             ...            ...               ...
# 10334      April   25     8         Morning              1                 0
# 10335      March    8    12         Morning              1                 0
# 10336   December   28     8         Morning              1                 0
# 10337       July   14    14       Afternoon              1                 0
# 10338    January    8    20       Afternoon              0                 0
#
#        Victims  Vehicles involved  Longitude   Latitude
# 0            2                  2   2.125624  41.340045
# 1            2                  2   2.120452  41.339426
# 2            5                  2   2.167356  41.360885
# 3            1                  2   2.124529  41.337668
# 4            1                  3   2.185272  41.416365
# ...        ...                ...        ...        ...
# 10334        1                  3   2.201800  41.392004
# 10335        1                  2   2.206013  41.443445
# 10336        1                  2   2.205607  41.443894
# 10337        1                  2   2.205118  41.444824
# 10338        0                  1   2.200956  41.437125
#
# [10339 rows x 15 columns]

# %% [markdown]
# Renomear District Name -> District_Name & Part of the day -> Part_of_the_day

# %%
accidents = accidents.rename(columns={'District Name': 'District_Name', 'Part of the day': 'Part_of_the_day'})
accidents
# Out:
#                     Id District_Name           Neighborhood Name  \
# 0      2017S008429           Unknown                     Unknown
# 1      2017S007316           Unknown                     Unknown
# 2      2017S010210           Unknown                     Unknown
# 3      2017S006364           Unknown                     Unknown
# 4      2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# ...                ...           ...                         ...
# 10334  2017S003667       Sant Andreu               el Bon Pastor
# 10335  2017S001896       Sant Andreu               el Bon Pastor
# 10336  2017S010718       Sant Andreu               el Bon Pastor
# 10337  2017S006145       Sant Andreu               el Bon Pastor
# 10338  2017S000178       Sant Andreu               el Bon Pastor
#
#                                                   Street    Weekday  \
# 0      Número 27                                     ...     Friday
# 1      Número 3 Zona Franca / Número 50 Zona Franca  ...     Friday
# 2      Litoral (Besòs)                               ...     Friday
# 3      Número 3 Zona Franca                          ...     Friday
# 4      Las Navas de Tolosa                           ...   Thursday
# ...                                                  ...        ...
# 10334  Litoral (Llobregat)                           ...    Tuesday
# 10335  PL MONTERREY                                  ...  Wednesday
# 10336  Litoral (Llobregat)                           ...   Thursday
# 10337  Litoral (Besòs)                               ...     Friday
# 10338  CIUTAT D'ASUNCIÓN                             ...     Sunday
#
#            Month  Day  Hour Part_of_the_day  Mild injuries  Serious injuries  \
# 0        October   13     8         Morning              2                 0
# 1      September    1    13         Morning              2                 0
# 2       December    8    21       Afternoon              5                 0
# 3           July   21     2           Night              1                 0
# 4            May   25    14       Afternoon              1                 0
# ...          ...  ...   ...             ...            ...               ...
# 10334      April   25     8         Morning              1                 0
# 10335      March    8    12         Morning              1                 0
# 10336   December   28     8         Morning              1                 0
# 10337       July   14    14       Afternoon              1                 0
# 10338    January    8    20       Afternoon              0                 0
#
#        Victims  Vehicles involved  Longitude   Latitude
# 0            2                  2   2.125624  41.340045
# 1            2                  2   2.120452  41.339426
# 2            5                  2   2.167356  41.360885
# 3            1                  2   2.124529  41.337668
# 4            1                  3   2.185272  41.416365
# ...        ...                ...        ...        ...
# 10334        1                  3   2.201800  41.392004
# 10335        1                  2   2.206013  41.443445
# 10336        1                  2   2.205607  41.443894
# 10337        1                  2   2.205118  41.444824
# 10338        0                  1   2.200956  41.437125
#
# [10339 rows x 15 columns]

# %% [markdown]
# Descobrir qual mês tem mais acidentes, agrupando dados por mês, depois contanto e colocando em ordem decrescente

# %%
month = accidents.groupby(by=['Month']).count().sort_values(by=['Id'],ascending=False)
month
# Out:
#             Id  District_Name  Neighborhood Name  Street  Weekday  Day  Hour  \
# Month
# November   991            991                991     991      991  991   991
# May        963            963                963     963      963  963   963
# March      935            935                935     935      935  935   935
# October    928            928                928     928      928  928   928
# July       918            918                918     918      918  918   918
# June       908            908                908     908      908  908   908
# April      845            845                845     845      845  845   845
# January    844            844                844     844      844  844   844
# February   824            824                824     824      824  824   824
# September  769            769                769     769      769  769   769
# December   762            762                762     762      762  762   762
# August     652            652                652     652      652  652   652
#
#            Part_of_the_day  Mild injuries  Serious injuries  Victims  \
# Month
# November               991            991               991      991
# May                    963            963               963      963
# March                  935            935               935      935
# October                928            928               928      928
# July                   918            918               918      918
# June                   908            908               908      908
# April                  845            845               845      845
# January                844            844               844      844
# February               824            824               824      824
# September              769            769               769      769
# December               762            762               762      762
# August                 652            652               652      652
#
#            Vehicles involved  Longitude  Latitude
# Month
# November                 991        991       991
# May                      963        963       963
# March                    935        935       935
# October                  928        928       928
# July                     918        918       918
# June                     908        908       908
# April                    845        845       845
# January                  844        844       844
# February                 824        824       824
# September                769        769       769
# December                 762        762       762
# August                   652        652       652

# %% [markdown]
# Descobrimos que novembro é o mês com mais acidentes, com isso filtramos o banco de dados, somente as linhas que apresentam "November" na coluna "Month", resetamos o index, para a contagem certa e excluimos a coluna gerada "index".

# %%
accidentsNovember = accidents.query('Month=="November"').reset_index(inplace=False).drop(columns=['index'])
accidentsNovember
# Out:
#                   Id District_Name           Neighborhood Name  \
# 0    2017S009296        Sant Martí  el Camp de l'Arpa del Clot
# 1    2017S009722        Sant Martí  el Camp de l'Arpa del Clot
# 2    2017S009302        Sant Martí                     el Clot
# 3    2017S009772        Sant Martí  el Camp de l'Arpa del Clot
# 4    2017S009684        Sant Martí     Provençals del Poblenou
# ..               ...           ...                         ...
# 986  2017S009471       Sant Andreu                 Sant Andreu
# 987  2017S009220       Sant Andreu                       Navas
# 988  2017S009619       Sant Andreu                 Sant Andreu
# 989  2017S009943       Sant Andreu                 Sant Andreu
# 990  2017S009145       Sant Andreu               el Bon Pastor
#
#                                                 Street    Weekday     Month  \
# 0    Indústria                                     ...   Thursday  November
# 1    Mallorca                                      ...  Wednesday  November
# 2    Meridiana                                     ...     Friday  November
# 3    Meridiana / València                          ...     Friday  November
# 4    Josep Pla / Perú                              ...    Tuesday  November
# ..                                                 ...        ...       ...
# 986  Torras i Bages                                ...  Wednesday  November
# 987  Espronceda / Josep Estivill                   ...  Wednesday  November
# 988  Arquímedes / Gran de Sant Andreu              ...     Sunday  November
# 989  Bartrina / Campeny                            ...  Wednesday  November
# 990  Ciutat d'Asunción / Fra Juníper Serra         ...     Sunday  November
#
#      Day  Hour Part_of_the_day  Mild injuries  Serious injuries  Victims  \
# 0      9    22           Night              1                 0        1
# 1     22    20       Afternoon              1                 0        1
# 2     10    11         Morning              1                 0        1
# 3     24     8         Morning              2                 0        2
# 4     21    22           Night              1                 0        1
# ..   ...   ...             ...            ...               ...      ...
# 986   15    15       Afternoon              1                 0        1
# 987    8     8         Morning              2                 0        2
# 988   19    20       Afternoon              1                 0        1
# 989   29    11         Morning              0                 1        1
# 990    5     9         Morning              2                 0        2
#
#      Vehicles involved  Longitude   Latitude
# 0                    1   2.176740  41.411445
# 1                    2   2.181955  41.408529
# 2                    1   2.187185  41.408131
# 3                    3   2.186877  41.410354
# 4                    2   2.206224  41.416095
# ..                 ...        ...        ...
# 986                  2   2.191275  41.438336
# 987                  1   2.187894  41.417940
# 988                  1   2.188260  41.441278
# 989                  1   2.186695  41.440430
# 990                  2   2.201479  41.434170
#
# [991 rows x 15 columns]

# %% [markdown]
# Vamos agora descobrir, qual o periodo do dia em novembro que ocorreu mais acidentes

# %%
accidentsNovemberP = accidentsNovember.groupby(by=['Part_of_the_day']).count()
accidentsNovemberP
# Out:
#                   Id  District_Name  Neighborhood Name  Street  Weekday  \
# Part_of_the_day
# Afternoon        501            501                501     501      501
# Morning          400            400                400     400      400
# Night             90             90                 90      90       90
#
#                  Month  Day  Hour  Mild injuries  Serious injuries  Victims  \
# Part_of_the_day
# Afternoon          501  501   501            501               501      501
# Morning            400  400   400            400               400      400
# Night               90   90    90             90                90       90
#
#                  Vehicles involved  Longitude  Latitude
# Part_of_the_day
# Afternoon                      501        501       501
# Morning                        400        400       400
# Night                           90         90        90

# %% [markdown]
# Agora o dia da semana que mais ocorreu mais acidentes

# %%
accidentsNovemberD = accidentsNovember.groupby(by=['Weekday']).count().sort_values(by=['Id'],ascending=False)
accidentsNovemberD
# Out:
#             Id  District_Name  Neighborhood Name  Street  Month  Day  Hour  \
# Weekday
# Thursday   199            199                199     199    199  199   199
# Friday     164            164                164     164    164  164   164
# Wednesday  163            163                163     163    163  163   163
# Tuesday    146            146                146     146    146  146   146
# Saturday   127            127                127     127    127  127   127
# Monday     122            122                122     122    122  122   122
# Sunday      70             70                 70      70     70   70    70
#
#            Part_of_the_day  Mild injuries  Serious injuries  Victims  \
# Weekday
# Thursday               199            199               199      199
# Friday                 164            164               164      164
# Wednesday              163            163               163      163
# Tuesday                146            146               146      146
# Saturday               127            127               127      127
# Monday                 122            122               122      122
# Sunday                  70             70                70       70
#
#            Vehicles involved  Longitude  Latitude
# Weekday
# Thursday                 199        199       199
# Friday                   164        164       164
# Wednesday                163        163       163
# Tuesday                  146        146       146
# Saturday                 127        127       127
# Monday                   122        122       122
# Sunday                    70         70        70

# %% [markdown]
# Agora vamos visualizar o distrito que em Novembro, que sofreu mais acidentes

# %%
accidentsNovemberDis = accidentsNovember.groupby(by=['District_Name']).count().sort_values(by=['Id'],ascending=False)
accidentsNovemberDis
# Out:
#                       Id  Neighborhood Name  Street  Weekday  Month  Day  \
# District_Name
# Eixample             310                310     310      310    310  310
# Sant Martí           124                124     124      124    124  124
# Sants-Montjuïc       105                105     105      105    105  105
# Sarrià-Sant Gervasi   98                 98      98       98     98   98
# Horta-Guinardó        78                 78      78       78     78   78
# Les Corts             68                 68      68       68     68   68
# Sant Andreu           68                 68      68       68     68   68
# Nou Barris            60                 60      60       60     60   60
# Gràcia                41                 41      41       41     41   41
# Ciutat Vella          37                 37      37       37     37   37
# Unknown                2                  2       2        2      2    2
#
#                      Hour  Part_of_the_day  Mild injuries  Serious injuries  \
# District_Name
# Eixample              310              310            310               310
# Sant Martí            124              124            124               124
# Sants-Montjuïc        105              105            105               105
# Sarrià-Sant Gervasi    98               98             98                98
# Horta-Guinardó         78               78             78                78
# Les Corts              68               68             68                68
# Sant Andreu            68               68             68                68
# Nou Barris             60               60             60                60
# Gràcia                 41               41             41                41
# Ciutat Vella           37               37             37                37
# Unknown                 2                2              2                 2
#
#                      Victims  Vehicles involved  Longitude  Latitude
# District_Name
# Eixample                 310                310        310       310
# Sant Martí               124                124        124       124
# Sants-Montjuïc           105                105        105       105
# Sarrià-Sant Gervasi       98                 98         98        98
# Horta-Guinardó            78                 78         78        78
# Les Corts                 68                 68         68        68
# Sant Andreu               68                 68         68        68
# Nou Barris                60                 60         60        60
# Gràcia                    41                 41         41        41
# Ciutat Vella              37                 37         37        37
# Unknown                    2                  2          2         2

# %% [markdown]
# Por últimos, vamos filtrar mais nossa tabela de novembro para as colunas -> distritos, dia e periodo

# %%
accidentsNovemberPDJ = accidentsNovember[['District_Name','Weekday','Part_of_the_day']].sort_values(by=['District_Name'], ascending=True)
accidentsNovemberPDJ
# Out:
#            District_Name   Weekday Part_of_the_day
# 528         Ciutat Vella  Thursday       Afternoon
# 128         Ciutat Vella    Monday           Night
# 127         Ciutat Vella   Tuesday         Morning
# 126         Ciutat Vella    Friday       Afternoon
# 529         Ciutat Vella    Friday         Morning
# ..                   ...       ...             ...
# 190  Sarrià-Sant Gervasi   Tuesday       Afternoon
# 194  Sarrià-Sant Gervasi  Thursday       Afternoon
# 342  Sarrià-Sant Gervasi   Tuesday       Afternoon
# 251              Unknown    Monday       Afternoon
# 771              Unknown    Monday       Afternoon
#
# [991 rows x 3 columns]

# %%
palette = sns.color_palette("rocket_r", as_cmap=True)
sns.displot(data=accidentsNovemberPDJ, x='Weekday', y='Part_of_the_day', palette=palette, cbar=True)
plt.title('Acidentes, por periodo e dia de novembro')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Thursday'),
#   Text(1, 0, 'Wednesday'),
#   Text(2, 0, 'Friday'),
#   Text(3, 0, 'Tuesday'),
#   Text(4, 0, 'Saturday'),
#   Text(5, 0, 'Monday'),
#   Text(6, 0, 'Sunday')])

# %% [markdown]
# Vamos agora ver os acidentes por dia e periodo distribuido por distrito

# %%
g = sns.displot(accidentsNovemberPDJ, col='District_Name', x='Weekday', y='Part_of_the_day', cbar=True)
g.set_xticklabels(rotation=90)

# %% [markdown]
# Vamos retomar nosso banco de dados original ('accidents') para fazer uma análise global, primeiro vamos ver o dia com mais ocorrência

# %%
weekday = accidents.groupby(by=['Weekday']).count().sort_values(by=['Id'],ascending=False)
weekday
# Out:
#              Id  District_Name  Neighborhood Name  Street  Month   Day  Hour  \
# Weekday
# Friday     1761           1761               1761    1761   1761  1761  1761
# Tuesday    1691           1691               1691    1691   1691  1691  1691
# Thursday   1677           1677               1677    1677   1677  1677  1677
# Wednesday  1650           1650               1650    1650   1650  1650  1650
# Monday     1510           1510               1510    1510   1510  1510  1510
# Saturday   1155           1155               1155    1155   1155  1155  1155
# Sunday      895            895                895     895    895   895   895
#
#            Part_of_the_day  Mild injuries  Serious injuries  Victims  \
# Weekday
# Friday                1761           1761              1761     1761
# Tuesday               1691           1691              1691     1691
# Thursday              1677           1677              1677     1677
# Wednesday             1650           1650              1650     1650
# Monday                1510           1510              1510     1510
# Saturday              1155           1155              1155     1155
# Sunday                 895            895               895      895
#
#            Vehicles involved  Longitude  Latitude
# Weekday
# Friday                  1761       1761      1761
# Tuesday                 1691       1691      1691
# Thursday                1677       1677      1677
# Wednesday               1650       1650      1650
# Monday                  1510       1510      1510
# Saturday                1155       1155      1155
# Sunday                   895        895       895

# %% [markdown]
# Vamos ver agora o periodo

# %%
PartDay = accidents.groupby(by=['Part_of_the_day']).count().sort_values(by=['Id'],ascending=False)
PartDay
# Out:
#                    Id  District_Name  Neighborhood Name  Street  Weekday  \
# Part_of_the_day
# Afternoon        5082           5082               5082    5082     5082
# Morning          4067           4067               4067    4067     4067
# Night            1190           1190               1190    1190     1190
#
#                  Month   Day  Hour  Mild injuries  Serious injuries  Victims  \
# Part_of_the_day
# Afternoon         5082  5082  5082           5082              5082     5082
# Morning           4067  4067  4067           4067              4067     4067
# Night             1190  1190  1190           1190              1190     1190
#
#                  Vehicles involved  Longitude  Latitude
# Part_of_the_day
# Afternoon                     5082       5082      5082
# Morning                       4067       4067      4067
# Night                         1190       1190      1190

# %% [markdown]
# o Distrito com mais ocorrência, também

# %%
DistrictAccidents = accidents.groupby(by=['District_Name']).count().sort_values(by=['Id'],ascending=False)
DistrictAccidents
# Out:
#                        Id  Neighborhood Name  Street  Weekday  Month   Day  \
# District_Name
# Eixample             3029               3029    3029     3029   3029  3029
# Sant Martí           1336               1336    1336     1336   1336  1336
# Sants-Montjuïc       1104               1104    1104     1104   1104  1104
# Sarrià-Sant Gervasi  1104               1104    1104     1104   1104  1104
# Horta-Guinardó        743                743     743      743    743   743
# Les Corts             726                726     726      726    726   726
# Ciutat Vella          600                600     600      600    600   600
# Sant Andreu           597                597     597      597    597   597
# Nou Barris            542                542     542      542    542   542
# Gràcia                531                531     531      531    531   531
# Unknown                27                 27      27       27     27    27
#
#                      Hour  Part_of_the_day  Mild injuries  Serious injuries  \
# District_Name
# Eixample             3029             3029           3029              3029
# Sant Martí           1336             1336           1336              1336
# Sants-Montjuïc       1104             1104           1104              1104
# Sarrià-Sant Gervasi  1104             1104           1104              1104
# Horta-Guinardó        743              743            743               743
# Les Corts             726              726            726               726
# Ciutat Vella          600              600            600               600
# Sant Andreu           597              597            597               597
# Nou Barris            542              542            542               542
# Gràcia                531              531            531               531
# Unknown                27               27             27                27
#
#                      Victims  Vehicles involved  Longitude  Latitude
# District_Name
# Eixample                3029               3029       3029      3029
# Sant Martí              1336               1336       1336      1336
# Sants-Montjuïc          1104               1104       1104      1104
# Sarrià-Sant Gervasi     1104               1104       1104      1104
# Horta-Guinardó           743                743        743       743
# Les Corts                726                726        726       726
# Ciutat Vella             600                600        600       600
# Sant Andreu              597                597        597       597
# Nou Barris               542                542        542       542
# Gràcia                   531                531        531       531
# Unknown                   27                 27         27        27

# %% [markdown]
# Por fim vamos ver novamente o mês com mais ocorrência também

# %%
month = accidents.groupby(by=['Month']).count().sort_values(by=['Id'],ascending=False)
month
# Out:
#             Id  District_Name  Neighborhood Name  Street  Weekday  Day  Hour  \
# Month
# November   991            991                991     991      991  991   991
# May        963            963                963     963      963  963   963
# March      935            935                935     935      935  935   935
# October    928            928                928     928      928  928   928
# July       918            918                918     918      918  918   918
# June       908            908                908     908      908  908   908
# April      845            845                845     845      845  845   845
# January    844            844                844     844      844  844   844
# February   824            824                824     824      824  824   824
# September  769            769                769     769      769  769   769
# December   762            762                762     762      762  762   762
# August     652            652                652     652      652  652   652
#
#            Part_of_the_day  Mild injuries  Serious injuries  Victims  \
# Month
# November               991            991               991      991
# May                    963            963               963      963
# March                  935            935               935      935
# October                928            928               928      928
# July                   918            918               918      918
# June                   908            908               908      908
# April                  845            845               845      845
# January                844            844               844      844
# February               824            824               824      824
# September              769            769               769      769
# December               762            762               762      762
# August                 652            652               652      652
#
#            Vehicles involved  Longitude  Latitude
# Month
# November                 991        991       991
# May                      963        963       963
# March                    935        935       935
# October                  928        928       928
# July                     918        918       918
# June                     908        908       908
# April                    845        845       845
# January                  844        844       844
# February                 824        824       824
# September                769        769       769
# December                 762        762       762
# August                   652        652       652

# %% [markdown]
# Um breve resumo do que já conseguimos
# Concluimos de acordo com as tabelas que:
# -Distrito com mais acidentes = Eixample(3029)
# -Mês com mais acidentes = Novembro(991)
# -Dia com mais acidentes = Sexta-Feira(1761)
# -Periodo com mais acidentes = Tarde(5082)

# %% [markdown]
# Vamos mostrar isso de forma gráfica, primeiro vamos resumir nosso banco de dados em Distrito, Mês, Dia e Periodo

# %%
AccidentsR = accidents[['District_Name','Month','Weekday','Part_of_the_day']].sort_values(by=['District_Name'], ascending=True)
AccidentsR
# Out:
#      District_Name     Month    Weekday Part_of_the_day
# 6568  Ciutat Vella     March     Friday       Afternoon
# 4039  Ciutat Vella     March     Sunday         Morning
# 4040  Ciutat Vella       May  Wednesday       Afternoon
# 4041  Ciutat Vella    August     Sunday       Afternoon
# 4042  Ciutat Vella  December   Thursday       Afternoon
# ...            ...       ...        ...             ...
# 1253       Unknown   January  Wednesday       Afternoon
# 1252       Unknown      June  Wednesday         Morning
# 1251       Unknown   October     Monday           Night
# 5072       Unknown   January     Monday         Morning
# 0          Unknown   October     Friday         Morning
#
# [10339 rows x 4 columns]

# %% [markdown]
# Vamos fazer um análise geral, gerando gráficos de acordo com mês e distrito, analisando o dia da semana e periodo

# %%
sns.displot(AccidentsR, col='Month', row='District_Name', x='Weekday', y='Part_of_the_day')

# %% [markdown]
# por fim, Vamos descompactar esses dados agora, em três análises, Distrito por Mês, Distrito, por dia e Distrito por Periodo

# %%
sns.displot(AccidentsR, x='District_Name', y='Month')
plt.xticks(rotation=90)
plt.title('Distrito por mês')

sns.displot(AccidentsR, x='District_Name', y='Weekday')
plt.xticks(rotation=90)
plt.title('Distrito por dia')

sns.displot(AccidentsR, x='District_Name', y='Part_of_the_day')
plt.xticks(rotation=90)
plt.title('Distrito por periodo')
# Out:
# Text(0.5, 1.0, 'Distrito por periodo')

# %% [markdown]
# CONCLUSÃO:

# %% [markdown]
# Em novembro(mês que ocorreu mais acidentes, 991)
# o Distrito:    Eixample(310, ou ~31,3%)
# o Dia:         Quinta-feira(199, ou ~20,1%)
# o Periodo:     Tarde(501, ou ~50,6)

# %% [markdown]
# No Geral(10.339)
# o Mês:         Novembro(991, ou ~9,6%)
# o Distrito:    Eixample(3029, ou ~29,3%)
# o Dia:         Sexta-Feira(1761, ou ~17%)
# o Periodo:     Tarde(5082, ou ~49,2%)
