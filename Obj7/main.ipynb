# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
transports = pd.read_csv('transports.csv')
bus_stops = pd.read_csv('bus_stops.csv')
transports = transports.rename(columns={'District.Name': 'District_Name'})
bus_stops = bus_stops.rename(columns={'District.Name': 'District_Name'})

# %%
transports
# Out:
#      Code         Transport  Longitude   Latitude  \
# 0    K001       Underground   2.119370  41.399203
# 1    K001       Underground   2.135427  41.397791
# 2    K001       Underground   2.185391  41.451492
# 3    K001       Underground   2.174473  41.460889
# 4    K001       Underground   2.168588  41.387200
# ..    ...               ...        ...        ...
# 646  K002     Railway (FGC)   2.118998  41.398967
# 647  K008  Maritime station   2.175248  41.352808
# 648  K008  Maritime station   2.174767  41.350955
# 649  K002     Railway (FGC)   2.131188  41.397617
# 650  K001       Underground   2.158822  41.375220
#
#                                                Station        District_Name  \
# 0    FGC (L6) - REINA ELISENDA (Sortida Duquesa d'O...  Sarrià-Sant Gervasi
# 1                              FGC (L6) - LA BONANOVA-  Sarrià-Sant Gervasi
# 2        METRO (L11) - CASA DE L'AIGUA (C. Vila-Real)-           Nou Barris
# 3      METRO (L11) - CIUTAT MERIDIANA (C. Pedraforca)-           Nou Barris
# 4           METRO (L1) - CATALUNYA (Rda. Universitat)-             Eixample
# ..                                                 ...                  ...
# 646                              FGC - REINA ELISENDA-  Sarrià-Sant Gervasi
# 647                       Terminal Marítima E *Creuers       Sants-Montjuïc
# 648                       Terminal Marítima D *Creuers       Sants-Montjuïc
# 649                     FGC - LES TRES TORRES<center>-  Sarrià-Sant Gervasi
# 650              METRO (L3) - POBLE SEC (C. de Manso)-             Eixample
#
#               Neighborhood.Name
# 0                        Sarrià
# 1        Sant Gervasi - Galvany
# 2              la Trinitat Nova
# 3              Ciutat Meridiana
# 4        la Dreta de l'Eixample
# ..                          ...
# 646                      Sarrià
# 647  la Marina del Prat Vermell
# 648  la Marina del Prat Vermell
# 649             les Tres Torres
# 650                 Sant Antoni
#
# [651 rows x 7 columns]

# %%
bus_stops
# Out:
#       Code       Transport  Longitude   Latitude          Bus.Stop  \
# 0     K014    Day bus stop   2.171619  41.413744        BUS -192--
# 1     K014    Day bus stop   2.134902  41.420222        BUS -124--
# 2     K014    Day bus stop   2.162913  41.423187        BUS -117--
# 3     K014    Day bus stop   2.163667  41.422899        BUS -117--
# 4     K014    Day bus stop   2.120212  41.397209        BUS -130--
# ...    ...             ...        ...        ...               ...
# 3157  K014    Day bus stop   2.183887  41.422024        BUS -191--
# 3158  K014    Day bus stop   2.176710  41.446419     BUS -127-81--
# 3159  K015  Night bus stop   2.144596  41.411446      NITBUS -N4--
# 3160  K014    Day bus stop   2.142256  41.371176  BUS -91-115-V5--
# 3161  K015  Night bus stop   2.134932  41.398495      NITBUS -N7--
#
#             District_Name          Neighborhood.Name
# 0          Horta-Guinardó                el Guinardó
# 1                  Gràcia  Vallcarca i els Penitents
# 2          Horta-Guinardó       la Font d'en Fargues
# 3          Horta-Guinardó       la Font d'en Fargues
# 4     Sarrià-Sant Gervasi                     Sarrià
# ...                   ...                        ...
# 3157          Sant Andreu   el Congrés i els Indians
# 3158           Nou Barris               les Roquetes
# 3159               Gràcia  Vallcarca i els Penitents
# 3160       Sants-Montjuïc                 la Bordeta
# 3161  Sarrià-Sant Gervasi     Sant Gervasi - Galvany
#
# [3162 rows x 7 columns]

# %%
transportsD = transports.groupby(by=['District_Name']).count().sort_values(by=['Code'],ascending=False)
transportsD
# Out:
#                      Code  Transport  Longitude  Latitude  Station  \
# District_Name
# Eixample              120        120        120       120      120
# Sant Martí             70         70         70        70       70
# Sarrià-Sant Gervasi    66         66         66        66       66
# Sants-Montjuïc         53         53         53        53       53
# Sant Andreu            40         40         40        40       40
# Nou Barris             39         39         39        39       39
# Horta-Guinardó         31         31         31        31       31
# Ciutat Vella           27         27         27        27       27
# Les Corts              24         24         24        24       24
# Gràcia                 17         17         17        17       17
#
#                      Neighborhood.Name
# District_Name
# Eixample                           120
# Sant Martí                          70
# Sarrià-Sant Gervasi                 66
# Sants-Montjuïc                      53
# Sant Andreu                         40
# Nou Barris                          39
# Horta-Guinardó                      31
# Ciutat Vella                        27
# Les Corts                           24
# Gràcia                              17

# %%
bus_stopsD = bus_stops.groupby(by=['District_Name']).count().sort_values(by=['Code'],ascending=False)
bus_stopsD
# Out:
#                      Code  Transport  Longitude  Latitude  Bus.Stop  \
# District_Name
# Sarrià-Sant Gervasi   439        439        439       439       439
# Sants-Montjuïc        415        415        415       415       415
# Eixample              405        405        405       405       405
# Horta-Guinardó        389        389        389       389       389
# Sant Martí            356        356        356       356       356
# Nou Barris            330        330        330       330       330
# Sant Andreu           228        228        228       228       228
# Gràcia                210        210        210       210       210
# Les Corts             207        207        207       207       207
# Ciutat Vella          167        167        167       167       167
#
#                      Neighborhood.Name
# District_Name
# Sarrià-Sant Gervasi                439
# Sants-Montjuïc                     415
# Eixample                           405
# Horta-Guinardó                     389
# Sant Martí                         356
# Nou Barris                         330
# Sant Andreu                        228
# Gràcia                             210
# Les Corts                          207
# Ciutat Vella                       167

# %%
transportE = transports.query('District_Name == "Eixample"')
bus_stopsE = bus_stops.query('District_Name == "Eixample"')

# %%
Code_bus = bus_stops[['Transport','Code']].groupby('Code')["Transport"].value_counts().to_frame()
Code_bus["Bus_Number"] = Code_bus["Transport"]
Code_bus = Code_bus.drop('Transport', axis='columns')
Code_bus
# Out:
#                        Bus_Number
# Code Transport
# K014 Day bus stop            2324
# K015 Night bus stop           828
# K016 Airport bus stop           7
# K017 Bus station                3

# %%
Code_transport = transportE[['Transport','Code']].groupby('Code')['Transport'].value_counts().to_frame()
Code_transport["Transp_Number"] = Code_transport["Transport"] 
Code_transport = Code_transport.drop('Transport', axis='columns')
Code_transport
# Out:
#                     Transp_Number
# Code Transport
# K001 Underground              103
# K002 Railway (FGC)              7
# K003 RENFE                      8
# K004 Airport train              1
# K011 Tram                       1

# %%
Transport_Eixamples = pd.concat([Code_bus, Code_transport], axis=1)
Transport_Eixamples = Transport_Eixamples['Bus_Number'].fillna(Transport_Eixamples['Transp_Number']).to_frame()
Transport_Eixamples = Transport_Eixamples.rename(columns={'Bus_Number':'Number of stops'})
Transport_Eixamples
# Out:
#                        Number of stops
# Code Transport
# K001 Underground                 103.0
# K002 Railway (FGC)                 7.0
# K003 RENFE                         8.0
# K004 Airport train                 1.0
# K011 Tram                          1.0
# K014 Day bus stop               2324.0
# K015 Night bus stop              828.0
# K016 Airport bus stop              7.0
# K017 Bus station                   3.0

# %%
bus_Stop = pd.concat([Transport_Eixamples.loc["K014"], Transport_Eixamples.loc["K015"]], axis=0)
bus_Stop
# Out:
#                 Number of stops
# Transport
# Day bus stop             2324.0
# Night bus stop            828.0
